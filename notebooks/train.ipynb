# %% [markdown]
# # FraudSense training
#
# EDA can be done in this notebook. To regenerate all artifacts (`model/*.pkl`, `sample_payload.json`), run from the project root:
#
# ```bash
# pip install -r backend/requirements.txt
# python notebooks/train_model.py
# ```
